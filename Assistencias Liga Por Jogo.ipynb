# %% [markdown]
# <a href="https://colab.research.google.com/github/dfvnunes/GTM-Setup/blob/main/Assistencias%20Liga%20Por%20Jogo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re

df = pd.read_excel('/content/Por_Jogo.xlsx', sheet_name=None)

df1=df['2012-2013']

df1
# Out:
#      Ranking          Jornada                            Jogo  Espectadores  \
# 0         1º      26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1        NaN  Liga Zon Sagres                             NaN           NaN
# 2         2º      28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3        NaN  Liga Zon Sagres                             NaN           NaN
# 4         3º      14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...      ...              ...                             ...           ...
# 1399     NaN     Segunda Liga                             NaN           NaN
# 1400    768º       Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401     NaN  Liga Zon Sagres                             NaN           NaN
# 1402    769º       Jornada 39   Vitória SC B 1 - 1 Leixões SC           0.0
# 1403     NaN     Segunda Liga                             NaN           NaN
#
#              Liga 1       Liga 2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            NaN          NaN
# 1400            NaN          NaN
# 1401            NaN          NaN
# 1402            NaN          NaN
# 1403            NaN          NaN
#
# [1404 rows x 6 columns]

# %%
df_drop = df1.drop('Ranking', axis=1)
df_drop
# Out:
#               Jornada                            Jogo  Espectadores  \
# 0         26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1     Liga Zon Sagres                             NaN           NaN
# 2         28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3     Liga Zon Sagres                             NaN           NaN
# 4         14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...               ...                             ...           ...
# 1399     Segunda Liga                             NaN           NaN
# 1400       Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401  Liga Zon Sagres                             NaN           NaN
# 1402       Jornada 39   Vitória SC B 1 - 1 Leixões SC           0.0
# 1403     Segunda Liga                             NaN           NaN
#
#              Liga 1       Liga 2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            NaN          NaN
# 1400            NaN          NaN
# 1401            NaN          NaN
# 1402            NaN          NaN
# 1403            NaN          NaN
#
# [1404 rows x 5 columns]

# %%
def abreviar_clubes_b_duas_colunas(df_drop, coluna1='Jogo', coluna2='Liga 2'):
    """
    Substitui os nomes completos dos clubes B pelos seus nomes abreviados
    nas duas colunas especificadas do DataFrame.

    Args:
        df (pd.DataFrame): O DataFrame do pandas.
        coluna1 (str): O nome da primeira coluna onde os clubes B estão presentes.
        coluna2 (str): O nome da segunda coluna onde os clubes B estão presentes.

    Returns:
        pd.DataFrame: O DataFrame com os nomes abreviados dos clubes B.
    """

    clubes_b = {
        'SL Benfica B': 'SLB B',
        'Sporting CP B': 'SCP B',
        'FC Porto B': 'FCP B',
        'SC Braga B': 'SCB B',
        'Vitória SC B': 'VSC B',
        'Marítimo B': 'CSM B'
    }

    # Expressão regular para extrair os nomes dos clubes B
    regex = r'(SL Benfica B|Sporting CP B|FC Porto B|SC Braga B|Vitória SC B|Marítimo B)'

    # Extrai e substitui os nomes dos clubes B na coluna 1
    df_drop[coluna1] = df_drop[coluna1].apply(lambda x: re.sub(regex, lambda m: clubes_b[m.group()], str(x)))

    # Substitui os nomes completos pelos abreviados na coluna 2
    df_drop[coluna2] = df_drop[coluna2].replace(clubes_b)

    return df_drop

# Exemplo de uso:
# Supondo que você tenha um DataFrame chamado 'df' e as colunas sejam 'Equipa1' e 'Equipa2'

# df = abreviar_clubes_b_duas_colunas(df, coluna1='Equipa1', coluna2='Equipa2')
# print(df)

# %%
df_drop = abreviar_clubes_b_duas_colunas(df_drop, coluna1='Jogo', coluna2='Liga 2')
df_drop
# Out:
#               Jornada                            Jogo  Espectadores  \
# 0         26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1     Liga Zon Sagres                             nan           NaN
# 2         28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3     Liga Zon Sagres                             nan           NaN
# 4         14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...               ...                             ...           ...
# 1399     Segunda Liga                             nan           NaN
# 1400       Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401  Liga Zon Sagres                             nan           NaN
# 1402       Jornada 39          VSC B 1 - 1 Leixões SC           0.0
# 1403     Segunda Liga                             nan           NaN
#
#              Liga 1       Liga 2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            NaN          NaN
# 1400            NaN          NaN
# 1401            NaN          NaN
# 1402            NaN          NaN
# 1403            NaN          NaN
#
# [1404 rows x 5 columns]

# %%
df_drop = df_drop.rename(columns={'Liga 1': 'Liga1'})
df_drop = df_drop.rename(columns={'Liga 2': 'Liga2'})

df_drop
# Out:
#               Jornada                            Jogo  Espectadores  \
# 0         26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1     Liga Zon Sagres                             nan           NaN
# 2         28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3     Liga Zon Sagres                             nan           NaN
# 4         14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...               ...                             ...           ...
# 1399     Segunda Liga                             nan           NaN
# 1400       Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401  Liga Zon Sagres                             nan           NaN
# 1402       Jornada 39          VSC B 1 - 1 Leixões SC           0.0
# 1403     Segunda Liga                             nan           NaN
#
#               Liga1        Liga2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            NaN          NaN
# 1400            NaN          NaN
# 1401            NaN          NaN
# 1402            NaN          NaN
# 1403            NaN          NaN
#
# [1404 rows x 5 columns]

# %%
df_drop.dtypes
# Out:
# Jornada          object
# Jogo             object
# Espectadores    float64
# Liga1            object
# Liga2            object
# dtype: object

# %%
df_drop['Jogo'] = df_drop['Jogo'].astype(str)
df_drop['Liga1'] = df_drop['Liga1'].astype(str)
df_drop
# Out:
#               Jornada                            Jogo  Espectadores  \
# 0         26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1     Liga Zon Sagres                             nan           NaN
# 2         28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3     Liga Zon Sagres                             nan           NaN
# 4         14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...               ...                             ...           ...
# 1399     Segunda Liga                             nan           NaN
# 1400       Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401  Liga Zon Sagres                             nan           NaN
# 1402       Jornada 39          VSC B 1 - 1 Leixões SC           0.0
# 1403     Segunda Liga                             nan           NaN
#
#               Liga1        Liga2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            nan          NaN
# 1400            nan          NaN
# 1401            nan          NaN
# 1402            nan          NaN
# 1403            nan          NaN
#
# [1404 rows x 5 columns]

# %%
def comparar_substrings(df_drop, Jogo, Liga1, Liga):

    def verificar_substring(row):
        # Remove NaN values from the Liga1 column before comparison
        liga1_values = [value for value in df_drop[Liga1].unique() if pd.notna(value)]

        # Check if any non-NaN value from 'Liga1' column is present in 'Jogo' column
        if any(liga1_value in row[Jogo] for liga1_value in liga1_values):
            return "Liga Zon Sagres"
        else:
            return "Segunda Liga"

    df_drop[Liga] = df_drop.apply(verificar_substring, axis=1)
    return df_drop

# %%
df_liga = comparar_substrings(df_drop, 'Jogo', 'Liga1', 'Liga')
df_liga
# Out:
#               Jornada                            Jogo  Espectadores  \
# 0         26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1     Liga Zon Sagres                             nan           NaN
# 2         28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3     Liga Zon Sagres                             nan           NaN
# 4         14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...               ...                             ...           ...
# 1399     Segunda Liga                             nan           NaN
# 1400       Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401  Liga Zon Sagres                             nan           NaN
# 1402       Jornada 39          VSC B 1 - 1 Leixões SC           0.0
# 1403     Segunda Liga                             nan           NaN
#
#               Liga1        Liga2             Liga
# 0      A. Académica  Atlético CP  Liga Zon Sagres
# 1         Beira-Mar         BSAD  Liga Zon Sagres
# 2       CD Nacional      CD Aves  Liga Zon Sagres
# 3     Estoril Praia  CD Feirense  Liga Zon Sagres
# 4     FC P.Ferreira   CD Tondela  Liga Zon Sagres
# ...             ...          ...              ...
# 1399            nan          NaN  Liga Zon Sagres
# 1400            nan          NaN  Liga Zon Sagres
# 1401            nan          NaN  Liga Zon Sagres
# 1402            nan          NaN     Segunda Liga
# 1403            nan          NaN  Liga Zon Sagres
#
# [1404 rows x 6 columns]

# %%
df_drop = df_drop.drop(['Liga1','Liga2'], axis=1)
df_drop
# Out:
#               Jornada                            Jogo  Espectadores  \
# 0         26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1     Liga Zon Sagres                             nan           NaN
# 2         28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3     Liga Zon Sagres                             nan           NaN
# 4         14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...               ...                             ...           ...
# 1399     Segunda Liga                             nan           NaN
# 1400       Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401  Liga Zon Sagres                             nan           NaN
# 1402       Jornada 39          VSC B 1 - 1 Leixões SC           0.0
# 1403     Segunda Liga                             nan           NaN
#
#                  Liga
# 0     Liga Zon Sagres
# 1     Liga Zon Sagres
# 2     Liga Zon Sagres
# 3     Liga Zon Sagres
# 4     Liga Zon Sagres
# ...               ...
# 1399  Liga Zon Sagres
# 1400  Liga Zon Sagres
# 1401  Liga Zon Sagres
# 1402     Segunda Liga
# 1403  Liga Zon Sagres
#
# [1404 rows x 4 columns]

# %%
df_drop = df_drop[~df_drop['Jornada'].isin(['Liga Zon Sagres', 'Segunda Liga'])]
df_drop
# Out:
#           Jornada                            Jogo  Espectadores  \
# 0     26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 2     28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 4     14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# 6      1ª Jornada       SL Benfica 2 - 2 SC Braga       53357.0
# 8     30ª Jornada  SL Benfica 3 - 1 Moreirense FC       51349.0
# ...           ...                             ...           ...
# 1394   Jornada 14        Naval 1 - 1 Portimonense         121.0
# 1396   Jornada 41          SC Covilhã 0 - 0 Naval         110.0
# 1398   Jornada 33               VSC B 2 - 2 Naval           0.0
# 1400   Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1402   Jornada 39          VSC B 1 - 1 Leixões SC           0.0
#
#                  Liga
# 0     Liga Zon Sagres
# 2     Liga Zon Sagres
# 4     Liga Zon Sagres
# 6     Liga Zon Sagres
# 8     Liga Zon Sagres
# ...               ...
# 1394     Segunda Liga
# 1396     Segunda Liga
# 1398     Segunda Liga
# 1400  Liga Zon Sagres
# 1402     Segunda Liga
#
# [702 rows x 4 columns]

# %%
df_drop.to_excel ('Por_Jogo_2012-2013.xlsx', index = False, header=True)
