# %% [markdown]
# <a href="https://colab.research.google.com/github/dfvnunes/GTM-Setup/blob/main/Assist%C3%AAncias_Liga_Original.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re

df = pd.read_excel('/content/Por_Jogo_upload.xlsx', sheet_name=None)

df1=df['2012-2013']

df1
# Out:
#      Ranking      Jornada                            Jogo  Espectadores  \
# 0         1º  26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1        NaN       Liga 1                             NaN           NaN
# 2         2º  28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3        NaN       Liga 1                             NaN           NaN
# 4         3º  14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...      ...          ...                             ...           ...
# 1399     NaN       Liga 2                             NaN           NaN
# 1400    768º   Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401     NaN       Liga 1                             NaN           NaN
# 1402    769º   Jornada 39   Vitória SC B 1 - 1 Leixões SC           0.0
# 1403     NaN       Liga 2                             NaN           NaN
#
#              Liga 1       Liga 2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            NaN          NaN
# 1400            NaN          NaN
# 1401            NaN          NaN
# 1402            NaN          NaN
# 1403            NaN          NaN
#
# [1404 rows x 6 columns]

# %%
df_drop = df1.drop('Ranking', axis=1)
df_drop
# Out:
#           Jornada                            Jogo  Espectadores  \
# 0     26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1          Liga 1                             NaN           NaN
# 2     28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3          Liga 1                             NaN           NaN
# 4     14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...           ...                             ...           ...
# 1399       Liga 2                             NaN           NaN
# 1400   Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401       Liga 1                             NaN           NaN
# 1402   Jornada 39   Vitória SC B 1 - 1 Leixões SC           0.0
# 1403       Liga 2                             NaN           NaN
#
#              Liga 1       Liga 2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            NaN          NaN
# 1400            NaN          NaN
# 1401            NaN          NaN
# 1402            NaN          NaN
# 1403            NaN          NaN
#
# [1404 rows x 5 columns]

# %%
def abreviar_clubes_b_duas_colunas(df_drop, coluna1='Jogo', coluna2='Liga 2'):
    """
    Substitui os nomes completos dos clubes B pelos seus nomes abreviados
    nas duas colunas especificadas do DataFrame.

    Args:
        df (pd.DataFrame): O DataFrame do pandas.
        coluna1 (str): O nome da primeira coluna onde os clubes B estão presentes.
        coluna2 (str): O nome da segunda coluna onde os clubes B estão presentes.

    Returns:
        pd.DataFrame: O DataFrame com os nomes abreviados dos clubes B.
    """

    clubes_b = {
        'SL Benfica B': 'SLB B',
        'Sporting CP B': 'SCP B',
        'FC Porto B': 'FCP B',
        'SC Braga B': 'SCB B',
        'Vitória SC B': 'VSC B',
        'Marítimo B': 'CSM B'
    }

    # Expressão regular para extrair os nomes dos clubes B
    regex = r'(SL Benfica B|Sporting CP B|FC Porto B|SC Braga B|Vitória SC B|Marítimo B)'

    # Extrai e substitui os nomes dos clubes B na coluna 1
    df_drop[coluna1] = df_drop[coluna1].apply(lambda x: re.sub(regex, lambda m: clubes_b[m.group()], str(x)))

    # Substitui os nomes completos pelos abreviados na coluna 2
    df_drop[coluna2] = df_drop[coluna2].replace(clubes_b)

    return df_drop

# %%
df_drop = abreviar_clubes_b_duas_colunas(df_drop, coluna1='Jogo', coluna2='Liga 2')
df_drop
# Out:
#           Jornada                            Jogo  Espectadores  \
# 0     26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1          Liga 1                             nan           NaN
# 2     28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3          Liga 1                             nan           NaN
# 4     14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...           ...                             ...           ...
# 1399       Liga 2                             nan           NaN
# 1400   Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401       Liga 1                             nan           NaN
# 1402   Jornada 39          VSC B 1 - 1 Leixões SC           0.0
# 1403       Liga 2                             nan           NaN
#
#              Liga 1       Liga 2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            NaN          NaN
# 1400            NaN          NaN
# 1401            NaN          NaN
# 1402            NaN          NaN
# 1403            NaN          NaN
#
# [1404 rows x 5 columns]

# %%
df_drop = df_drop.rename(columns={'Liga 1': 'Liga1'})
df_drop = df_drop.rename(columns={'Liga 2': 'Liga2'})

df_drop
# Out:
#           Jornada                            Jogo  Espectadores  \
# 0     26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1          Liga 1                             nan           NaN
# 2     28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3          Liga 1                             nan           NaN
# 4     14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...           ...                             ...           ...
# 1399       Liga 2                             nan           NaN
# 1400   Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401       Liga 1                             nan           NaN
# 1402   Jornada 39          VSC B 1 - 1 Leixões SC           0.0
# 1403       Liga 2                             nan           NaN
#
#               Liga1        Liga2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            NaN          NaN
# 1400            NaN          NaN
# 1401            NaN          NaN
# 1402            NaN          NaN
# 1403            NaN          NaN
#
# [1404 rows x 5 columns]

# %%
df_drop.dtypes
# Out:
# Jornada          object
# Jogo             object
# Espectadores    float64
# Liga1            object
# Liga2            object
# dtype: object

# %%
df_drop['Jogo'] = df_drop['Jogo'].astype(str)
df_drop['Liga1'] = df_drop['Liga1'].astype(str)
df_drop
# Out:
#           Jornada                            Jogo  Espectadores  \
# 0     26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1          Liga 1                             nan           NaN
# 2     28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3          Liga 1                             nan           NaN
# 4     14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...           ...                             ...           ...
# 1399       Liga 2                             nan           NaN
# 1400   Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401       Liga 1                             nan           NaN
# 1402   Jornada 39          VSC B 1 - 1 Leixões SC           0.0
# 1403       Liga 2                             nan           NaN
#
#               Liga1        Liga2
# 0      A. Académica  Atlético CP
# 1         Beira-Mar         BSAD
# 2       CD Nacional      CD Aves
# 3     Estoril Praia  CD Feirense
# 4     FC P.Ferreira   CD Tondela
# ...             ...          ...
# 1399            nan          NaN
# 1400            nan          NaN
# 1401            nan          NaN
# 1402            nan          NaN
# 1403            nan          NaN
#
# [1404 rows x 5 columns]

# %%
def comparar_substrings(df_drop, Jogo, Liga1, Liga):

    def verificar_substring(row):
        # Remove NaN values from the Liga1 column before comparison
        liga1_values = [value for value in df_drop[Liga1].unique() if pd.notna(value)]

        # Verifica se valores non-NaN em 'Liga1' estão presentes em 'Jogo'
        if any(liga1_value in row[Jogo] for liga1_value in liga1_values):
            return "Liga 1"
        else:
            return "Liga 2"

    df_drop[Liga] = df_drop.apply(verificar_substring, axis=1)
    return df_drop

# %%
df_liga = comparar_substrings(df_drop, 'Jogo', 'Liga1', 'Liga')
df_liga
# Out:
#           Jornada                            Jogo  Espectadores  \
# 0     26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0
# 1          Liga 1                             nan           NaN
# 2     28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0
# 3          Liga 1                             nan           NaN
# 4     14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0
# ...           ...                             ...           ...
# 1399       Liga 2                             nan           NaN
# 1400   Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0
# 1401       Liga 1                             nan           NaN
# 1402   Jornada 39          VSC B 1 - 1 Leixões SC           0.0
# 1403       Liga 2                             nan           NaN
#
#               Liga1        Liga2    Liga
# 0      A. Académica  Atlético CP  Liga 1
# 1         Beira-Mar         BSAD  Liga 1
# 2       CD Nacional      CD Aves  Liga 1
# 3     Estoril Praia  CD Feirense  Liga 1
# 4     FC P.Ferreira   CD Tondela  Liga 1
# ...             ...          ...     ...
# 1399            nan          NaN  Liga 1
# 1400            nan          NaN  Liga 1
# 1401            nan          NaN  Liga 1
# 1402            nan          NaN  Liga 2
# 1403            nan          NaN  Liga 1
#
# [1404 rows x 6 columns]

# %%
df_drop = df_drop.drop(['Liga1','Liga2'], axis=1)
df_drop
# Out:
#           Jornada                            Jogo  Espectadores    Liga
# 0     26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0  Liga 1
# 1          Liga 1                             nan           NaN  Liga 1
# 2     28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0  Liga 1
# 3          Liga 1                             nan           NaN  Liga 1
# 4     14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0  Liga 1
# ...           ...                             ...           ...     ...
# 1399       Liga 2                             nan           NaN  Liga 1
# 1400   Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0  Liga 1
# 1401       Liga 1                             nan           NaN  Liga 1
# 1402   Jornada 39          VSC B 1 - 1 Leixões SC           0.0  Liga 2
# 1403       Liga 2                             nan           NaN  Liga 1
#
# [1404 rows x 4 columns]

# %%
df_drop = df_drop[~df_drop['Jornada'].isin(['Liga 1', 'Liga 2'])]
df_drop
# Out:
#           Jornada                            Jogo  Espectadores    Liga
# 0     26ª Jornada    SL Benfica 2 - 0 Sporting CP       62553.0  Liga 1
# 2     28ª Jornada  SL Benfica 1 - 1 Estoril Praia       60897.0  Liga 1
# 4     14ª Jornada       SL Benfica 2 - 2 FC Porto       60556.0  Liga 1
# 6      1ª Jornada       SL Benfica 2 - 2 SC Braga       53357.0  Liga 1
# 8     30ª Jornada  SL Benfica 3 - 1 Moreirense FC       51349.0  Liga 1
# ...           ...                             ...           ...     ...
# 1394   Jornada 14        Naval 1 - 1 Portimonense         121.0  Liga 2
# 1396   Jornada 41          SC Covilhã 0 - 0 Naval         110.0  Liga 2
# 1398   Jornada 33               VSC B 2 - 2 Naval           0.0  Liga 2
# 1400   Jornada 27  Vitória SC 2 - 2 FC P.Ferreira           0.0  Liga 1
# 1402   Jornada 39          VSC B 1 - 1 Leixões SC           0.0  Liga 2
#
# [702 rows x 4 columns]

# %%
def extrair_numero_jornada(df_drop, coluna='Jornada'):
    """
    Extrai o número da jornada da coluna especificada.

    Args:
        df (pd.DataFrame): O DataFrame do pandas.
        coluna (str): O nome da coluna com os valores da jornada.

    Returns:
        pd.DataFrame: O DataFrame com os números das jornadas extraídos.
    """

    def extrair_numero(valor):
        """Extrai o número da jornada de um valor."""
        match = re.search(r'(\d+)', str(valor))
        if match:
            return match.group(1)
        return valor  # Retorna o valor original se não encontrar um número

    df_drop[coluna] = df_drop[coluna].apply(extrair_numero)
    return df_drop

# %%
df_drop = extrair_numero_jornada(df_drop, coluna='Jornada')
df_drop
# Out:
# <ipython-input-17-6712bca3c8b5>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_drop[coluna] = df_drop[coluna].apply(extrair_numero)
#      Jornada                            Jogo  Espectadores    Liga
# 0         26    SL Benfica 2 - 0 Sporting CP       62553.0  Liga 1
# 2         28  SL Benfica 1 - 1 Estoril Praia       60897.0  Liga 1
# 4         14       SL Benfica 2 - 2 FC Porto       60556.0  Liga 1
# 6          1       SL Benfica 2 - 2 SC Braga       53357.0  Liga 1
# 8         30  SL Benfica 3 - 1 Moreirense FC       51349.0  Liga 1
# ...      ...                             ...           ...     ...
# 1394      14        Naval 1 - 1 Portimonense         121.0  Liga 2
# 1396      41          SC Covilhã 0 - 0 Naval         110.0  Liga 2
# 1398      33               VSC B 2 - 2 Naval           0.0  Liga 2
# 1400      27  Vitória SC 2 - 2 FC P.Ferreira           0.0  Liga 1
# 1402      39          VSC B 1 - 1 Leixões SC           0.0  Liga 2
#
# [702 rows x 4 columns]

# %%
df_drop['Jornada'] = pd.to_numeric(df_drop['Jornada'], errors='coerce').astype('Int64')
df_drop
# Out:
# <ipython-input-21-bf73a997307c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_drop['Jornada'] = pd.to_numeric(df_drop['Jornada'], errors='coerce').astype('Int64')
#       Jornada                            Jogo  Espectadores    Liga
# 0          26    SL Benfica 2 - 0 Sporting CP       62553.0  Liga 1
# 2          28  SL Benfica 1 - 1 Estoril Praia       60897.0  Liga 1
# 4          14       SL Benfica 2 - 2 FC Porto       60556.0  Liga 1
# 6           1       SL Benfica 2 - 2 SC Braga       53357.0  Liga 1
# 8          30  SL Benfica 3 - 1 Moreirense FC       51349.0  Liga 1
# ...       ...                             ...           ...     ...
# 1394       14        Naval 1 - 1 Portimonense         121.0  Liga 2
# 1396       41          SC Covilhã 0 - 0 Naval         110.0  Liga 2
# 1398       33               VSC B 2 - 2 Naval           0.0  Liga 2
# 1400       27  Vitória SC 2 - 2 FC P.Ferreira           0.0  Liga 1
# 1402       39          VSC B 1 - 1 Leixões SC           0.0  Liga 2
#
# [702 rows x 4 columns]

# %%
df_drop['Espectadores'] = pd.to_numeric(df_drop['Espectadores'], errors='coerce').astype('Int64')
df_drop
# Out:
# <ipython-input-22-0e0e78dfe24c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_drop['Espectadores'] = pd.to_numeric(df_drop['Espectadores'], errors='coerce').astype('Int64')
#       Jornada                            Jogo  Espectadores    Liga
# 0          26    SL Benfica 2 - 0 Sporting CP         62553  Liga 1
# 2          28  SL Benfica 1 - 1 Estoril Praia         60897  Liga 1
# 4          14       SL Benfica 2 - 2 FC Porto         60556  Liga 1
# 6           1       SL Benfica 2 - 2 SC Braga         53357  Liga 1
# 8          30  SL Benfica 3 - 1 Moreirense FC         51349  Liga 1
# ...       ...                             ...           ...     ...
# 1394       14        Naval 1 - 1 Portimonense           121  Liga 2
# 1396       41          SC Covilhã 0 - 0 Naval           110  Liga 2
# 1398       33               VSC B 2 - 2 Naval             0  Liga 2
# 1400       27  Vitória SC 2 - 2 FC P.Ferreira             0  Liga 1
# 1402       39          VSC B 1 - 1 Leixões SC             0  Liga 2
#
# [702 rows x 4 columns]

# %%
df_drop.to_excel ('Por_Jogo_2012-2013.xlsx', index = False, header=True)
